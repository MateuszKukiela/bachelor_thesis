# %%
import os
import numpy as np
import mne
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy.signal as ss
from scipy.stats import kurtosis
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import pandas as pd
from mne.viz import plot_epochs_image
from autoreject import AutoReject
from autoreject import Ransac
from autoreject import get_rejection_threshold 
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
def get_bad_epochs(signal, percentile=25): #shape = ( epochs, channels, samples)
    channels = signal.shape[1]
    Qstd = np.std(signal,axis = -1)
    Qkurt = kurtosis(signal,axis = -1)
    bads = np.empty(0)
    for i in range(channels):
        Q1,Q3 = np.percentile(Qstd[:,i],[percentile,100-percentile])
        IQR = Q3-Q1
        range_std = (Q1-1.5*IQR,Q3+1.5*IQR)
        Q1,Q3 = np.percentile(Qkurt[:,i],[percentile,100-percentile])
        IQR = Q3-Q1
        range_kurt = (Q1-1.5*IQR,Q3+1.5*IQR)
        right_std = np.where(Qstd[:,i] > range_std[1])[0]
        left_std = np.where(Qstd[:,i] < range_std[0])[0]
        right_kurt = np.where(Qkurt[:,i] > range_kurt[1])[0]
        left_kurt = np.where(Qkurt[:,i] < range_kurt[0])[0]
        bads = np.unique(np.concatenate((bads,left_kurt,right_kurt,left_std,right_std)))
    return bads

def get_bad_channels(signal,percentile=30): #shape = (channels, samples)
    channels = signal.shape[1]
    Qstd = np.std(signal,axis = -1)
    Qkurt = kurtosis(signal,axis = -1)
    bads = np.empty(0)
    Q1,Q3 = np.percentile(Qstd,[percentile,100-percentile])
    IQR = Q3-Q1
    range_std = (Q1-1.5*IQR,Q3+1.5*IQR)
    Q1,Q3 = np.percentile(Qkurt,[percentile,100-percentile])
    IQR = Q3-Q1
    range_kurt = (Q1-1.5*IQR,Q3+1.5*IQR)
    right_std = np.where(Qstd > range_std[1])[0]
    left_std = np.where(Qstd < range_std[0])[0]
    right_kurt = np.where(Qkurt > range_kurt[1])[0]
    left_kurt = np.where(Qkurt < range_kurt[0])[0]
    bads = np.unique(np.concatenate((bads,left_kurt,right_kurt,left_std,right_std)))
    return bads
# mistakes = [True if i['word_type']!=i['decision'] else False for i in f.event['tag_type']]
# epo.drop(mistakes)
def getting_proper_decisions_ind(raw_file):
    pseudos = [i for i, trial in enumerate(raw_file.event['tag_type']) if trial['word_type']=='p' and trial['word_type']==trial['decision']]
    words = [i for i, trial in enumerate(raw_file.event['tag_type']) if trial['word_type']=='s' and trial['word_type']==trial['decision']]
    return pseudos, words

# %% [markdown]
# ## Checkin if signals are cut accordingly to diode signal

# %%
data_path = './data/2_LDT/'

# %%
f = mne.io.read_raw_eeglab(data_path+'k2.set',preload=True)
ile = len(f.event['latency'])
EVENTS = np.zeros((ile,3))
EVENTS[:,0] = f.event['latency']
EVENTS[:,1] = 0
EVENTS[:,2] = 1
t = np.arange(-0.2,1.001,1/1024)
epo = mne.Epochs(f,EVENTS.astype(int),baseline = (-0.2,0),tmin= -0.2, tmax=1)
syg = epo.get_data()
# Out:
# Reading ./data/2_LDT/k2.fdt
# Reading 0 ... 5092671  =      0.000 ...  4973.312 secs...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1464bb241c9f> in <module>
# ----> 1 f = mne.io.read_raw_eeglab(data_path+'k2.set',preload=True)
#       2 ile = len(f.event['latency'])
#       3 EVENTS = np.zeros((ile,3))
#       4 EVENTS[:,0] = f.event['latency']
#       5 EVENTS[:,1] = 0
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in read_raw_eeglab(input_fname, eog, preload, uint16_codec, verbose)
#     220     .. versionadded:: 0.11.0
#     221     """
# --> 222     return RawEEGLAB(input_fname=input_fname, preload=preload,
#     223                      eog=eog, verbose=verbose, uint16_codec=uint16_codec)
#     224
#
# <decorator-gen-197> in __init__(self, input_fname, eog, preload, uint16_codec, verbose)
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in __init__(self, input_fname, eog, preload, uint16_codec, verbose)
#     354
#     355         # create event_ch from annotations
# --> 356         annot = read_annotations(input_fname)
#     357         self.set_annotations(annot)
#     358         _check_boundary(annot, None)
#
# ~/Desktop/mne-python/mne/annotations.py in read_annotations(fname, sfreq, uint16_codec)
#     666
#     667     elif name.endswith('set'):
# --> 668         annotations = _read_annotations_eeglab(fname,
#     669                                                uint16_codec=uint16_codec)
#     670
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in _read_annotations_eeglab(eeg, uint16_codec)
#     597     """
#     598     if isinstance(eeg, str):
# --> 599         eeg = _check_load_mat(eeg, uint16_codec=uint16_codec)
#     600
#     601     if not hasattr(eeg, 'event'):
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in _check_load_mat(fname, uint16_codec)
#      57     """Check if the mat struct contains 'EEG'."""
#      58     from ...externals.pymatreader import read_mat
# ---> 59     eeg = read_mat(fname, uint16_codec=uint16_codec)
#      60     if 'ALLEEG' in eeg:
#      61         raise NotImplementedError(
#
# ~/Desktop/mne-python/mne/externals/pymatreader/pymatreader.py in read_mat(filename, variable_names, ignore_fields, uint16_codec)
#      80     try:
#      81         with open(filename, 'rb') as fid:  # avoid open file warnings on error
# ---> 82             raw_data = scipy.io.loadmat(fid, struct_as_record=True,
#      83                                         squeeze_me=True, mat_dtype=False,
#      84                                         variable_names=variable_names,
#
# ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     216     with _open_file_context(file_name, appendmat) as f:
#     217         MR, _ = mat_reader_factory(f, **kwargs)
# --> 218         matfile_dict = MR.get_variables(variable_names)
#     219
#     220     if mdict is not None:
#
# ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     290                 continue
#     291             try:
# --> 292                 res = self.read_var_array(hdr, process)
#     293             except MatReadError as err:
#     294                 warnings.warn(
#
# ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     250            `process`.
#     251         '''
# --> 252         return self._matrix_reader.array_from_header(header, process)
#     253
#     254     def get_variables(self, variable_names=None):
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_struct()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_mi_matrix()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_struct()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_mi_matrix()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio_utils.pyx in scipy.io.matlab.mio_utils.squeeze_element()
#
# mio_utils.pyx in scipy.io.matlab.mio_utils.squeeze_element()
#
# <__array_function__ internals> in squeeze(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.plot(t,syg[1608,-2])
plt.show()

# %% [markdown]
#  jeśli dla każdego trialu obliczycie np. std napięcia, obliczycie Q1 i Q3 (25 i 75 percentyl otrzymanych wartości) to outliery są to te wartości, które leżą poza zakresem [Q1-1.5*IQR, q3+1.5*IQR] , gdzie IQR = Q3-Q1; analogicznie dla kurtozy.

# %% [markdown]
# ## Searching for bad channels

# %%
bads = np.empty(0)
for i in range(1,19):
    for gender in ('k','m'):
        filename = data_path + gender + f'{i}.set'
        f = mne.io.read_raw_eeglab(filename,preload=True)
        f.set_eeg_reference(ref_channels=['A1','A2'])
        f.drop_channels(['EOG','dioda','TSS','A1','A2'])
        f.filter(1,50)
        signals = f.get_data()
        bads = np.concatenate((bads,get_bad_channels(signals)))
# Out:
# Reading ./data/2_LDT/k1.fdt
# Reading 0 ... 4466687  =      0.000 ...  4361.999 secs...
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 3379 samples (3.300 sec)
#
# Reading ./data/2_LDT/m1.fdt
# Reading 0 ... 4939295  =      0.000 ...  4823.530 secs...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1131069b69d1> in <module>
#       3     for gender in ('k','m'):
#       4         filename = data_path + gender + f'{i}.set'
# ----> 5         f = mne.io.read_raw_eeglab(filename,preload=True)
#       6         f.set_eeg_reference(ref_channels=['A1','A2'])
#       7         f.drop_channels(['EOG','dioda','TSS','A1','A2'])
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in read_raw_eeglab(input_fname, eog, preload, uint16_codec, verbose)
#     220     .. versionadded:: 0.11.0
#     221     """
# --> 222     return RawEEGLAB(input_fname=input_fname, preload=preload,
#     223                      eog=eog, verbose=verbose, uint16_codec=uint16_codec)
#     224
#
# <decorator-gen-197> in __init__(self, input_fname, eog, preload, uint16_codec, verbose)
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in __init__(self, input_fname, eog, preload, uint16_codec, verbose)
#     332             logger.info('Reading %s' % data_fname)
#     333
# --> 334             super(RawEEGLAB, self).__init__(
#     335                 info, preload, filenames=[data_fname], last_samps=last_samps,
#     336                 orig_format='double', verbose=verbose)
#
# <decorator-gen-146> in __init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#
# ~/Desktop/mne-python/mne/io/base.py in __init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#     245         self._update_times()
#     246         if load_from_disk:
# --> 247             self._preload_data(preload)
#     248         self._init_kwargs = _get_argvalues()
#     249
#
# <decorator-gen-150> in _preload_data(self, preload, verbose)
#
# ~/Desktop/mne-python/mne/io/base.py in _preload_data(self, preload, verbose)
#     503         logger.info('Reading %d ... %d  =  %9.3f ... %9.3f secs...' %
#     504                     (0, len(self.times) - 1, 0., self.times[-1]))
# --> 505         self._data = self._read_segment(data_buffer=data_buffer)
#     506         assert len(self._data) == self.info['nchan']
#     507         self.preload = True
#
# <decorator-gen-148> in _read_segment(self, start, stop, sel, data_buffer, projector, verbose)
#
# ~/Desktop/mne-python/mne/io/base.py in _read_segment(***failed resolving arguments***)
#     392             # reindex back to original file
#     393             orig_idx = _convert_slice(self._read_picks[fi][idx])
# --> 394             _ReadSegmentFileProtector(self)._read_segment_file(
#     395                 data[:, this_sl], orig_idx, fi,
#     396                 int(start_file), int(stop_file), cals, mult)
#
# ~/Desktop/mne-python/mne/io/base.py in _read_segment_file(self, *args, **kwargs)
#    1788
#    1789     def _read_segment_file(self, *args, **kwargs):
# -> 1790         return self.__raw.__class__._read_segment_file(self, *args, **kwargs)
#    1791
#    1792
#
# ~/Desktop/mne-python/mne/io/eeglab/eeglab.py in _read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#     365     def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
#     366         """Read a chunk of raw data."""
# --> 367         _read_segments_file(
#     368             self, data, idx, fi, start, stop, cals, mult, dtype='<f4')
#     369
#
# ~/Desktop/mne-python/mne/io/utils.py in _read_segments_file(raw, data, idx, fi, start, stop, cals, mult, dtype, n_channels, offset, trigger_ch)
#     216         for sample_start in np.arange(0, data_left, block_size) // n_channels:
#     217             count = min(block_size, data_left - sample_start * n_channels)
# --> 218             block = np.fromfile(fid, dtype, count)
#     219             if block.size != count:
#     220                 raise RuntimeError('Incorrect number of samples (%s != %s), '
#
# KeyboardInterrupt:

# %%
np.save('./temp/bad_channels.npy',np.unique(bads))

# %%
np.save('./temp/good_channels.npy', np.array([3,5,6,9,10,14,15]))

# %% [markdown]
# ## Developing proper code for preprocessing raw signal

# %%
def reading_data(filename,bad_ch,tmin= -0.2, tmax=1):
    f = mne.io.read_raw_eeglab(filename,preload=True,verbose='warning')
    chann = f.ch_names
    ile = len(f.event['latency'])
    EVENTS = np.zeros((ile,3))
    EVENTS[:,0] = f.event['latency']
    EVENTS[:,1] = 0
    EVENTS[:,2] = 1
    f.set_eeg_reference(ref_channels=['A1','A2'])
    f.drop_channels(['EOG','dioda','TSS','A1','A2'])
    f.filter(1,40)
#     f.drop_channels(np.array(chann)[bad_ch.astype(int)])
#     signals = f.get_data()
#     bads = get_bad_channels(signals)
#     f.info['bads'] = np.array(chann)[bads.astype(int)]
#     f.plot()
#     print(f.info['bads'])
#     f = f.interpolate_bads(reset_bads=True, verbose=True, origin=np.array([0,0,0]))
#     f.plot()
    syg_raw = f.get_data()
    epo = mne.Epochs(f,EVENTS.astype(int),baseline = (-0.2,0),tmin=tmin, tmax=tmax,metadata = pd.DataFrame(f.event['tag_type']),verbose='warning', preload=True)
    mistakes = [True if epo._metadata['word_type'][i]!=epo._metadata['decision'][i] else False for i in range(0, len(epo))]
    epo.drop(mistakes)
    syg = epo.get_data()
    epo.drop(get_bad_epochs(syg))
    word_type = np.array([0 if i == 'p' else 1 for i in epo._metadata['word_type']])
    # xDAWN
#     plot_epochs_image(epo)
    epo.plot()

    picks = mne.pick_types(epo.info, meg=False, eeg=True,
                       stim=False, eog=False,
                       include=[], exclude=[])
    ransac = Ransac(verbose='progressbar', picks=picks, n_jobs=3)
    epo = ransac.fit_transform(epo)
    
    ar = AutoReject(n_jobs=3)
    epo = ar.fit_transform(epo)

    reject = get_rejection_threshold(epo, decim=2)
    epo.drop_bad(reject=reject)
    epo.plot()
    temp_syg = epo.get_data()
    temp_syg = temp_syg.reshape([temp_syg.shape[1],temp_syg.shape[0]*temp_syg.shape[2]])
    signal_cov = mne.compute_raw_covariance(mne.io.RawArray(temp_syg, epo[0].info))
    xd = mne.preprocessing.Xdawn(n_components=2, signal_cov=signal_cov)
    xd.fit(epo)
    epochs_denoised = xd.apply(epo)
    epo = next(iter(epochs_denoised.values()))

    epo.plot()
#     plot_epochs_image(epo)
    return word_type, epo

# %%
y = np.empty(0)
# X = np.zeros((0,7,1230))
X = np.zeros((0,19,1230))
bad = np.load('./temp/bad_channels.npy')
for i in range(1,2):
    for gender in ('k','m'):
        filename = data_path + gender + f'{i}.set'
        typ,epo=reading_data(filename,bad,tmin= -0.2, tmax=1)
        y = np.concatenate((y,typ))
#         X.append(epo)
        sig = epo.get_data()
        X = np.concatenate((X,sig))
# Out:
# Iterating epochs ...
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    3.7s remaining:    0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4ec4e5b21345> in <module>
#       6     for gender in ('k','m'):
#       7         filename = data_path + gender + f'{i}.set'
# ----> 8         typ,epo=reading_data(filename,bad,tmin= -0.2, tmax=1)
#       9         y = np.concatenate((y,typ))
#      10 #         X.append(epo)
#
# <ipython-input-4-95c3f49f4dc6> in reading_data(filename, bad_ch, tmin, tmax)
#      33                        include=[], exclude=[])
#      34     ransac = Ransac(verbose='progressbar', picks=picks, n_jobs=3)
# ---> 35     epo = ransac.fit_transform(epo)
#      36
#      37     ar = AutoReject(n_jobs=3)
#
# ~/.local/lib/python3.8/site-packages/autoreject/ransac.py in fit_transform(self, epochs)
#     228
#     229     def fit_transform(self, epochs):
# --> 230         return self.fit(epochs).transform(epochs)
#
# ~/.local/lib/python3.8/site-packages/autoreject/ransac.py in fit(self, epochs)
#     200                             for random_state in np.arange(0, n_epochs, n_jobs)]
#     201         epoch_idxs = np.array_split(np.arange(n_epochs), n_jobs)
# --> 202         corrs = parallel(my_iterator(self, epochs, idxs, chs, verbose)
#     203                          for idxs, chs in zip(epoch_idxs, self.ch_subsets_))
#     204         self.corr_ = np.concatenate(corrs)
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     538         AsyncResults.get from multiprocessing."""
#     539         try:
# --> 540             return future.result(timeout=timeout)
#     541         except CfTimeoutError:
#     542             raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
X.shape
# Out:
# (2113, 7, 1230)

# %%
X.shape
# Out:
# (1922, 7, 1230)

# %%
epo.info
# Out:
# <Info | 9 non-empty values
#  bads: []
#  ch_names: O1, O2, T5, P3, Pz, P4, T6, T3, C3, Cz, C4, T4, F7, F3, Fz, F4, ...
#  chs: 19 EEG
#  custom_ref_applied: True
#  dig: 24 items (24 EEG)
#  highpass: 1.0 Hz
#  lowpass: 40.0 Hz
#  meas_date: unspecified
#  nchan: 19
#  projs: []
#  sfreq: 1024.0 Hz
# >

# %%
import pickle
PIK = "./processed_data/2_LDT_epochs.dat"

with open(PIK, "wb") as f:
    pickle.dump(X, f)

# %%
np.save('./processed_data/2_LDT_y_xDAWN_4_autoreject.npy',y)

# %%
np.save('./processed_data/2_LDT_X_xDAWN_4_autoreject.npy',X)

# %%
X.shape
# Out:
# (41461, 7, 1230)

# %%
epo._metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c2566556a82c> in <module>
# ----> 1 epo._metadata
#
# NameError: name 'epo' is not defined

# %%
# !python3 --version
# Out:
# Python 3.8.2

# %%
X.shape
# Out:
# (42744, 7, 1230)

# %%
y.shape
# Out:
# (42744,)

# %%
np.save('X_new.npy',X)
np.save('y_new.npy',y)

# %%
niezero = np.nonzero(y)[0]
zero = np.where(y == 0)[0]

# %%
pseudo_X = X[zero,:,:]
word_X = X[niezero,:,:]

# %%
mean_pseudo = np.mean(pseudo_X,axis=0)
mean_word = np.mean(word_X,axis=0)
# Out:
# (7, 1230)

# %%
for i in range(7):
    plt.plot(t,mean_pseudo[i,:])
    plt.plot(t,mean_word[i,:])
    plt.show()

# %%
epo.ch_names
# Out:
# ['P3', 'P4', 'T6', 'Cz', 'C4', 'Fz', 'F4']
