# %%
import mne
import numpy as np
import os

# %%
raw = mne.io.read_epochs_eeglab('./data/B01_exp1.set')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-1155d30018a2> in <module>
# ----> 1 raw = mne.io.read_epochs_eeglab('./data/B01_exp1.set')
#
# ~/.local/lib/python3.8/site-packages/mne/io/eeglab/eeglab.py in read_epochs_eeglab(input_fname, events, event_id, eog, verbose, uint16_codec)
#     275     .. versionadded:: 0.11.0
#     276     """
# --> 277     epochs = EpochsEEGLAB(input_fname=input_fname, events=events, eog=eog,
#     278                           event_id=event_id, verbose=verbose,
#     279                           uint16_codec=uint16_codec)
#
# <decorator-gen-198> in __init__(self, input_fname, events, event_id, tmin, baseline, reject, flat, reject_tmin, reject_tmax, montage, eog, verbose, uint16_codec)
#
# ...

# %%
# !ls
# Out:
# '01 - about-throat-singing.m3u8'
# '02 - throat-singing-of-different-nations.m3u8'
# '03 - what-is-throat-singing.m3u8'
# '04 - introduction.m3u8'
# '05 - about-kargyraa-style (1).m3u8'
# '05 - about-kargyraa-style.m3u8'
#  07756881989_FS-34418_20_AVPL1_04_fv.pdf
# '08 - how-to-learn-kargyraa.m3u8'
# '09 - kargyraa-style-exercises.m3u8'
# '10 - Rukia.swf'
# '11 - HK Girl.swf'
#  1222428273101168640-png__700.jpg
# '12 - HK Girl 2.swf'
# '13 - Sakai.swf'
# '14 - HK Girl 3.swf'
# '15 - HK Girl 4.swf'
# '16 - Kuririn.swf'
# '17 - Seru.swf'
# '18 - LAZER.swf'
#  1_LDT_v1-20191209T231933Z-001.zip
# '24 - Raven.swf'
# '26 - Raven 2.swf'
# '2 - Kylie Griffin.swf'
#  2_LDT-20200522T123822Z-005.zip
#  2_LDT-20200522T123822Z-008.zip
#  2_LDT-20200522T123822Z-010.zip
# '31 - Starfire.swf'
# '(3) Facebook.mp4'
# '3 - Kim Possible.swf'
#  3way%20rocker%20switch%20led%20control_bb.webp
# '41 - Hatsune Miku.swf'
# '45 - Jinx.swf'
# '47 - Frankie Foster.swf'
# '49 - HK Girl 5.swf'
# ...
